# %%
import requests

# %%
from fake_useragent import UserAgent

ua = UserAgent()

# %%
# 设置fake-agent
headers = {
    'user-agent': ua.chrome
}

# 创建Session，获取cookie
s = requests.Session()

# 三亚首页
r = s.get('http://www.mafengwo.cn/travel-scenic-spot/mafengwo/10030.html', headers=headers)
r.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>\n<title>2017三亚旅游攻略,三亚自由行攻略,蚂蜂窝三亚出游攻略游记 - 蚂蜂窝</title>\n<meta name="description" content="2017三亚旅游攻略,介绍了三亚旅游景点、线路、美食、住宿、地图等三亚旅游攻略信息,了解三亚旅游等自由行攻略信息来蚂蜂窝旅游攻略网。" />\n<meta name="keywords" content="2017三亚旅游攻略,三亚自助游,三亚自由行" />\n<link rel="canonical" href="http://www.mafengwo.cn/travel-scenic-spot/mafengwo/10030.html"/>\n<script type="text/javascript">\nwindow.Env = {"MDDID":10030,"MDDADM":0,"isCnmain":true,"WWW_HOST":"www.mafengwo.cn","IMG_HOST":"images.mafengwo.net","P_HOST":"passport.mafengwo.cn","P_HTTP":"https:\\/\\/passport.mafengwo.cn","UID":0,"CSTK":"dd02531b2fd224a9f4f4166729151d72_7804a0dcd149e54a157f3f8442c77f12","GOOGLE_MAP_KEY":"AIzaSyD-Su0x_rPy1xehlMBcMyTqWkU49Bk53nQ"};\n</script>\n\n<link href="http://css.mafengwo.net/css/cv/css+base:css+jquery.suggest:css+plugins:css+plugins+jquery.jgrowl:css+other+popup:css+mfw-header.2015^YlVS^1493708283.css" rel="stylesheet" type="text/css"
# ...

# %%
# 获取游记的ajax api
url = 'http://www.mafengwo.cn/gonglve/ajax.php?act=get_travellist'

# 设置参数
place_id = 10030
page_number = 1

payload = {
    'mddid': place_id,
    'pageid': 'mdd_index',
    'sort': 1,
    'cost': 0,
    'days': 0,
    'month': 0,
    'tagid': 0,
    'page': page_number
}

# post
r = s.post(url, headers=headers, data=payload)

# list中为html的文本，解析其中的item，获取各个游记的链接
r.text
# Out:
# '{"msg":"succ","list":"<div class=\\"tn-list\\">\\n                <div class=\\"tn-item clearfix\\">\\n        <div class=\\"tn-image\\">\\n            <a href=\\"\\/i\\/7208420.html\\" target=\\"_blank\\">\\n                <img class=\\"lazy\\" data-original=\\"http:\\/\\/c4-q.mafengwo.net\\/s10\\/M00\\/5B\\/11\\/wKgBZ1lcwU-AYzt9AAgCizOnCgw44.jpeg?imageMogr2%2Fthumbnail%2F%21250x185r%2Fgravity%2FCenter%2Fcrop%2F%21250x185%2Fquality%2F90\\" width=\\"220\\" height=\\"150\\" alt=\\"\\u00b7\\u521d\\u590f\\uff0c\\u4e00\\u8def\\u5357\\u884c\\u4e4b\\u5317\\u7eac18\\u00b0C\\uff0c\\u6211\\u548c\\u78a7\\u6d77\\u84dd\\u5929\\u6709\\u4e2a\\u7ea6\\u4f1a_\\u6e38\\u8bb0\\">\\n                                    \\n                            <\\/a>\\n        <\\/div>\\n        <div class=\\"tn-wrapper\\" data-focus=\\"\\" data-topsort=\\"1\\" data-star=\\"0\\">\\n            <dl>\\n                <dt class=\\"hasxjicon\\">\\n                                            <a class=\\"bzicon\\" href
# ...

# %%
r.content
# Out:
# b'{"msg":"succ","list":"<div class=\\"tn-list\\">\\n                <div class=\\"tn-item clearfix\\">\\n        <div class=\\"tn-image\\">\\n            <a href=\\"\\/i\\/7208420.html\\" target=\\"_blank\\">\\n                <img class=\\"lazy\\" data-original=\\"http:\\/\\/c4-q.mafengwo.net\\/s10\\/M00\\/5B\\/11\\/wKgBZ1lcwU-AYzt9AAgCizOnCgw44.jpeg?imageMogr2%2Fthumbnail%2F%21250x185r%2Fgravity%2FCenter%2Fcrop%2F%21250x185%2Fquality%2F90\\" width=\\"220\\" height=\\"150\\" alt=\\"\\u00b7\\u521d\\u590f\\uff0c\\u4e00\\u8def\\u5357\\u884c\\u4e4b\\u5317\\u7eac18\\u00b0C\\uff0c\\u6211\\u548c\\u78a7\\u6d77\\u84dd\\u5929\\u6709\\u4e2a\\u7ea6\\u4f1a_\\u6e38\\u8bb0\\">\\n                                    \\n                            <\\/a>\\n        <\\/div>\\n        <div class=\\"tn-wrapper\\" data-focus=\\"\\" data-topsort=\\"1\\" data-star=\\"0\\">\\n            <dl>\\n                <dt class=\\"hasxjicon\\">\\n                                            <a class=\\"bzicon\\" hre
# ...

# %%
import json

result = r.json()

log_list = result['list']

# %%
from bs4 import BeautifulSoup

log_item = BeautifulSoup(log_list, 'lxml')
log_item_list = log_item.select('.tn-item')

print(len(log_item_list))

for item in log_item_list:
    log_bs_obj = item.select('.tn-wrapper')[0].select('dt > a')[0]
    print(log_bs_obj.text, log_bs_obj['href'])
# Out:
# 10
#  http://www.mafengwo.cn/i/588664.html
#  http://www.mafengwo.cn/i/588664.html
# ·海的意义——2017说走就走的海南三亚之旅 /i/7088240.html
# 请到天涯海角来 /i/7501745.html
# 三亚新玩法：“玩购”碧海蓝天的奢享周末 /gonglve/ziyouxing/1208.html?cid=1010606
# APP javascript:void(0);
# ·海边微风起，等风也等你 | 带着闺蜜去三亚吹吹北纬18度的风 /i/6987440.html
# APP javascript:void(0);
# ·夏末，邂逅橘色温度的三亚。【告诉你一个好吃好玩的三亚】 /i/6645893.html
# APP javascript:void(0);

# %%
r_log = requests.get('http://www.mafengwo.cn/i/5460989.html')
html_bs_obj = BeautifulSoup(r_log.content.decode('utf-8'), 'lxml')

# print(r_log.text)
# r_log.content.decode('utf-8')

# %%
# 大标题
title = html_bs_obj.select('h1')[0].text
# 出发时间
start_time = html_bs_obj.select('.time')[1].text.split(r'/')[1]
# 出行天数
days = html_bs_obj.select('.day')[0].text.split(r'/')[1]
# 内容
log_content = html_bs_obj.find(class_='va_con').text

print(title, start_time)
print(log_content.strip())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-59f26bb08c03> in <module>()
#       2 title = html_bs_obj.select('h1')[0].text
#       3 # 出发时间
# ----> 4 start_time = html_bs_obj.select('.time')[1].text.split(r'/')[1]
#       5 # 出行天数
#       6 days = html_bs_obj.select('.day')[0].text.split(r'/')[1]
#
# IndexError: list index out of range

# %%
total_obj = html_bs_obj.find(class_='vc_total')
words, imgs = total_obj.find_all('span')
total_obj.find(class_='_j_total_person').text
html_bs_obj.find_all(class_='add_pic')
# Out:
# [<div class="add_pic _j_anchorcnt _j_seqitem" data-pid="126095613" data-seq="126191883" id="_j_photo_126095613" style="width:680px">
#  <a href="/photo/10030/scenery_5460989/126095613.html" style="display: block" target="_blank">
#  <img alt="" class="_j_lazyload" data-pid="126095613" data-rt-src="https://a4-q.mafengwo.net/s9/M00/8E/2C/wKgBs1cUPcqAOXbyAAjAwAxZp5U34.jpeg?imageView2%2F2%2Fw%2F1360%2Fq%2F90" data-src="https://a4-q.mafengwo.net/s9/M00/8E/2C/wKgBs1cUPcqAOXbyAAjAwAxZp5U34.jpeg?imageView2%2F2%2Fw%2F680%2Fq%2F90" src="..." style="height:453px;width:680px;background:#FCF2DC"/>
#  </a>
#  </div>,
#  <div class="add_pic _j_anchorcnt _j_seqitem" data-pid="126095564" data-seq="126384472" id="_j_photo_126095564" style="width:680px">
#  <a href="/photo/10030/scenery_5460989/126095564.html" style="display: block" target="_blank">
# ...
